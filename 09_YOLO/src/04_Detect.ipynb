# %% [markdown]
# ### 00.01_Sample

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.predict(source="../data/classification_sample.jpg", conf=0.2, save=True)

print(results)
# Out:
# /home/jhj/venv/YOLOv8_venv/lib/python3.10/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# image 1/1 /home/jhj/dev_ws/09_YOLO/src/../data/classification_sample.jpg: 384x640 6 cars, 1 bus, 52.8ms
# Speed: 2.6ms preprocess, 52.8ms inference, 551.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
# object detection을 수행할 이미지rock_scissor_paper
origin_img = Image.open('../data/classification_sample.jpg')
# object detection을 완료한 이미지
detect_img = Image.open('./runs/detect/predict5/classification_sample.jpg')
# matplotlib을 이용한 2개 이상 이미지 출력
fig, ax = plt.subplots(ncols=2, figsize=(20, 15))
ax[0].imshow(origin_img)
ax[0].set_title('Origin Image')
ax[1].imshow(detect_img)
ax[1].set_title('Detect Image')
plt.show()

# %% [markdown]
# ### 00.02_Data set
# [Data set link](https://public.roboflow.com/object-detection/aquarium/2), YOLOv8

# %% [markdown]
# ### 01_Train

# %%
# %pwd
# Out:
# '/home/jhj/dev_ws/09_YOLO/src'

# %% [markdown]
# Edit file: Home/.config/Utralytics/settings.yaml
#
# datasets_dir: /home/jhj/dev_ws/09_YOLO/data

# %%
from ultralytics import YOLO

model=YOLO('yolov8n.pt')

results = model.train(data='../data/Aquarium/data.yaml', epochs=25)
# Out:
# /home/jhj/venv/YOLOv8_venv/lib/python3.10/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Core(TM) i7-10750H 2.60GHz)
# ...

# %%
# %pwd
# Out:
# '/home/jhj/dev_ws/09_YOLO/src'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 이미지 열기
img = mpimg.imread('./runs/train11/results.png')

# 이미지 크기 조정
long_edge_size = 2000
aspect_ratio = img.shape[1] / img.shape[0]
resized_img = plt.figure(figsize=(long_edge_size / 100, long_edge_size / 100 * aspect_ratio))
plt.imshow(img)
plt.axis('off')  # 축 제거
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 import matplotlib.image as mpimg
#       4 # 이미지 열기
# ----> 5 img = mpimg.imread('./runs/train11/results.png')
#       7 # 이미지 크기 조정
#       8 long_edge_size = 2000
#
# File ~/venv/YOLOv8_venv/lib/python3.10/site-packages/matplotlib/image.py:1544, in imread(fname, format)
#    1537 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1538     # Pillow doesn't handle URLs directly.
#    1539     raise ValueError(
#    1540         "Please open the URL for reading and pass the "
#    1541         "result to Pillow, e.g. with "
#    1542         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1543         )
# -> 1544 with img_open(fname) as image:
#    1545     return (_pil_png_to_float_array(image)
# ...
